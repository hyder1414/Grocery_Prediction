# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.offline as py
import plotly.tools as tls
import plotly.graph_objs as go
import plotly.tools as tls

# %%
traindf = pd.read_csv("walmartSample.csv")
df = pd.read_csv("walmart.csv")

# %%
traindf.head()
# Out:
#    Unnamed: 0       X  Store        Date  IsHoliday  Dept  Weekly_Sales  \
# 0      202017  202017     21  2011-02-25      False    36       1025.00
# 1      165520  165520     17  2012-03-02      False    31       1236.64
# 2      389207  389207     41  2011-12-02      False    94      37971.00
# 3      133193  133193     14  2011-05-06      False    67      26400.02
# 4      401356  401356     43  2010-10-08      False     1       8748.54
#
#    Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0        61.27       3.065        NaN        NaN        NaN        NaN
# 1        26.28       3.242   14469.08    1163.89      37.38     8771.3
# 2        34.53       3.378    4594.56     305.47    1781.24     3168.1
# 3        58.21       4.046        NaN        NaN        NaN        NaN
# 4        72.81       2.633        NaN        NaN        NaN        NaN
#
#    MarkDown5         CPI  Unemployment Type    Size
# 0        NaN  213.190421         8.028    B  140167
# ...

# %%
traindf.shape
# Out:
# (500, 18)

# %%
traindf.isnull().sum() / len(traindf.index) *100
# Out:
# Unnamed: 0       0.0
# X                0.0
# Store            0.0
# Date             0.0
# IsHoliday        0.0
# Dept             0.0
# Weekly_Sales     0.0
# Temperature      0.0
# Fuel_Price       0.0
# MarkDown1       66.0
# MarkDown2       75.0
# MarkDown3       69.0
# MarkDown4       69.2
# MarkDown5       65.6
# CPI              0.0
# Unemployment     0.0
# Type             0.0
# Size             0.0
# dtype: float64

# %%
df.isnull().sum() / len(df.index) *100
# Out:
# Unnamed: 0       0.000000
# Store            0.000000
# Date             0.000000
# IsHoliday        0.000000
# Dept             0.414575
# Weekly_Sales     0.414575
# Temperature      0.000000
# Fuel_Price       0.000000
# MarkDown1       63.991496
# MarkDown2       73.417115
# MarkDown3       67.245497
# MarkDown4       67.763302
# MarkDown5       63.813382
# CPI              0.138192
# Unemployment     0.138192
# Type             0.000000
# Size             0.000000
# dtype: float64

# %%
sns.set(style="white")

# Compute the correlation matrix
corr = traindf.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(100, 4, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(traindf['MarkDown1'], ax = axs[0])
plt2 = sns.boxplot(traindf['MarkDown5'], ax = axs[1])
plt3 = sns.boxplot(traindf['Weekly_Sales'], ax = axs[2])
plt.tight_layout()

# %%
sns.pairplot(traindf, x_vars=['MarkDown2', 'MarkDown5', 'Size'], y_vars='Weekly_Sales', height=4, aspect=1, kind='scatter')
plt.show()
